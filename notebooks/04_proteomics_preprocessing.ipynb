# %% [markdown]
# # Proteomics
# Extract timepoints from dataset and create new dataset from it
# Creates new *mid_processing_datasets* folder and parquet files during runtime
# For this part of the Dataset it is important to understand what SeqId and SomaId is
# Structure:
# - SeqId: `PPPP-CC-v | <Pool>-<Clone>-<version>`
# - SomaId:

# %%
from src.common_imports import *
from src.data_audit import data_audit
from src.somascan import *
from src.save_wrapper import save_report
from src.extraction import extract_dtypes
from src.check_data import *
from src.normalization import *
from src.low_variance_report import low_variance_report
from src.visualize import *
# Out:
# Loading Libraries
# Done loading

# %%
data = load()
# Out:
# Loading somascan...
# Done loading!

# %%
print("Indexing data...")
df_exp = data['df_expMatrix']
df_samp = data['df_sampMatrix']
print("Done!")
# Out:
# Indexing data...
# Done!

# %%
# data analysis of raw data
save_report(data_audit, df_exp, "expression matrix")
save_report(data_audit,df_samp, "sample matrix")
save_report(low_variance_report, df_exp, "expression matrix")
save_report(low_variance_report, df_samp, "sample matrix")
# Out:
# Saved: ../reports/expression matrix_data_audit.txt
# Saved: ../reports/sample matrix_data_audit.txt
# Saved: ../reports/expression matrix_low_variance_report.txt
# Saved: ../reports/sample matrix_low_variance_report.txt

# %%
# save splits
splits = reshape_and_split(df_exp=df_exp, df_samp=df_samp)

# save splits
save_splits(splits)

# create glossary
create_gene_lookup(df_exp)
# Out:
# Timepoints found: ['6month', 'Baseline']
#   6month: (97, 1311)
#   Baseline: (140, 1311)
# Saved: ../mid_processing_datasets/expression_matrix_6month.parquet
# Saved: ../mid_processing_datasets/expression_matrix_baseline.parquet
# Saved: ../mid_processing_datasets/gene_lookup.parquet
#            EntrezGeneSymbol EntrezGeneID    Target  \
# SeqId
# 2597-8_3              VEGFA         7422      VEGF
# 2654-19_1          TNFRSF1A         7132  TNF sR-I
# 2788-55_1              MMP3         4314     MMP-3
# 2967-8_1              VCAM1         7412    VCAM-1
# 3046-31_1              RETN        56729  resistin
# ...                     ...          ...       ...
# 9211-19_3          SERPINF1         5176      PEDF
# 9212-22_3              CTSF         8722      CATF
# 9213-24_3              FTCD        10841      FTCD
# 9215-117_3            USP25        29761     UBP25
# 9216-100_3           PLXNB2        23654     PLXB2
#
#                                                TargetFullName UniProt
# SeqId
# 2597-8_3                 Vascular endothelial growth factor A  P15692
# 2654-19_1   Tumor necrosis factor receptor superfamily mem...  P19438
# 2788-55_1                                       Stromelysin-1  P08254
# 2967-8_1                     Vascular cell adhesion protein 1  P19320
# 3046-31_1                                            Resistin  Q9HD89
# ...                                                       ...     ...
# 9211-19_3                   Pigment epithelium-derived factor  P36955
# 9212-22_3                                         Cathepsin F  Q9UBX1
# 9213-24_3               Formimidoyltransferase-cyclodeaminase  O95954
# 9215-117_3           Ubiquitin carboxyl-terminal hydrolase 25  Q9UHP3
# 9216-100_3                                          Plexin-B2  O15031
#
# [1310 rows x 5 columns]

# %%
# pulling saved data
df_exp_bl = pd.read_parquet("../mid_processing_datasets/expression_matrix_baseline.parquet")
df_exp_6m = pd.read_parquet("../mid_processing_datasets/expression_matrix_6month.parquet")
print("done reading")
# Out:
# done reading

# %%
# running data audit on newly formed data
save_report(data_audit, df_exp_bl, "baseline expression matrix")
save_report(data_audit, df_exp_6m, "6 months expression matrix")
save_report(low_variance_report,df_exp_bl, "baseline expression matrix")
save_report(low_variance_report, df_exp_6m, "6 months expression matrix")
# Out:
# Saved: ../reports/baseline expression matrix_data_audit.txt
# Saved: ../reports/6 months expression matrix_data_audit.txt
# Saved: ../reports/baseline expression matrix_low_variance_report.txt
# Saved: ../reports/6 months expression matrix_low_variance_report.txt

# %%
df_exp_bl.head()
df_exp_6m.head()
# Out:
# SeqId      Patient_ID  2597-8_3  2654-19_1  2788-55_1  2967-8_1  3046-31_1  \
# SampleId
# TAC1075_M6    TAC1075   11993.7     1358.4      585.6   14119.3      997.0
# TAC1148_M6    TAC1148   11000.8     1087.1      602.3   13485.6     1186.2
# TAC1179_M6    TAC1179   15116.4     1205.6      382.9   13505.8     1155.5
# TAC1225_M6    TAC1225   12873.1     2062.8     1243.5   20003.1     1864.4
# TAC1209_M6    TAC1209   10796.4     1178.1     1136.9   15152.3     1364.6
#
# SeqId       4336-2_1  4337-49_2  4673-13_2  4867-15_2  ...  9199-6_3  \
# SampleId                                               ...
# TAC1075_M6    2150.9    81794.4      512.9      633.8  ...    3776.1
# TAC1148_M6     342.0    16741.7      222.5      417.4  ...    4251.7
# TAC1179_M6     413.7   116629.2      383.2     1135.1  ...   10580.8
# TAC1225_M6     301.3   119197.3      274.8      398.6  ...    6877.5
# TAC1209_M6     863.3   131055.7      273.4      435.8  ...    4859.8
#
# SeqId       9201-13_3  9202-309_3  9204-33_3  9207-60_3  9211-19_3  9212-22_3  \
# SampleId
# TAC1075_M6     2515.1      1780.4     1248.7     1799.0    55797.4     2078.4
# TAC1148_M6     3025.8      1769.1      500.5     3253.0    59882.3     2515.2
# TAC1179_M6     5813.3      3905.4      568.0     1714.8    61199.4     1863.4
# TAC1225_M6     3461.2      3426.8      668.2     2726.7    72002.7     2514.8
# TAC1209_M6     3049.0      1912.6      515.5     2130.7    56690.5     2221.6
#
# SeqId       9213-24_3  9215-117_3  9216-100_3
# SampleId
# TAC1075_M6     9340.3      1061.8      5881.7
# TAC1148_M6    10679.1       913.7      5373.4
# TAC1179_M6     3418.3       780.7      4142.3
# TAC1225_M6    13206.6       699.5      5775.7
# TAC1209_M6    12061.3       887.9      4544.7
#
# [5 rows x 1311 columns]

# %%
extract_dtypes(df_exp_bl, verbose=True)
# Out:
# Schema of total values
# (column, row)
# Absolute Values: (140, 1311)
# ['Patient_ID', '2597-8_3', '2654-19_1', '2788-55_1', '2967-8_1', '3046-31_1', '4336-2_1', '4337-49_2', '4673-13_2', '4867-15_2', '4924-32_1', '5509-7_3', '8484-24_3', '10336-3_3', '10337-83_3', '10339-48_3', '10342-55_3', '10344-334_3', '10346-5_3', '10351-51_3', '10356-21_3', '10358-33_3', '10361-25_3', '10362-35_3', '10363-13_3', '10364-6_3', '10365-132
# String values: (140, 1)
# ['Patient_ID']
# Object values: (140, 0)
# []
# (SeqId      Patient_ID  2597-8_3  2654-19_1  2788-55_1  2967-8_1  3046-31_1  \
#  SampleId
#  TAC1145_BL    TAC1145   16301.7     1628.1      689.4   12386.8     1732.7
#  TAC1000_BL    TAC1000   10421.1     1220.8      426.4   11669.8     1042.4
#  TAC1058_BL    TAC1058    9352.7     1337.1      668.6   15387.8     2402.8
#  TAC1150_BL    TAC1150   11279.3     1355.2      390.8   12320.6     1350.4
#  TAC1174_BL    TAC1174   10622.2     1062.2      671.9   16307.8     1323.5
#  ...               ...       ...        ...        ...       ...        ...
#  TAC1042_BL    TAC1042    9384.1      943.9      814.4   10377.0     2250.5
#  TAC1232_BL    TAC1232   11154.9     1281.2     1889.8   17802.6     1633.2
#  TAC1082_BL    TAC1082    6652.2     1636.0     1102.0   11790.8      979.0
#  TAC1179_BL    TAC1179   16324.1     1614.3      601.3   15779.1     1683.5
#  VAC2038_BL    VAC2038    7696.6     1052.6      740.3   10938.4     1233.0
#
#  SeqId       4336-2_1  4337-49_2  4673-13_2  4867-15_2  ...  9199-6_3  \
#  SampleId                                               ...
#  TAC1145_BL    2461.5   146207.9      559.6     1556.6  ...    7101.8
#  TAC1000_BL    1676.3   157654.1      787.4      512.5  ...    5669.6
#  TAC1058_BL    1377.1   142311.8      225.7      499.3  ...    6163.6
#  TAC1150_BL     216.0    41350.3      266.6      541.4  ...    5003.9
#  TAC1174_BL     418.5    87174.8      232.8      429.1  ...    8339.7
#  ...              ...        ...        ...        ...  ...       ...
#  TAC1042_BL    1604.1   168041.4      390.0      582.6  ...    6390.7
#  TAC1232_BL    2509.2   106927.8      676.0      607.3  ...    5062.3
#  TAC1082_BL    8813.5    92119.4      195.4      980.7  ...    6730.9
#  TAC1179_BL     872.9   157544.8      490.7     1247.4  ...   12071.1
#  VAC2038_BL    6032.5    20577.7      239.6      435.0  ...    4858.7
#
#  SeqId       9201-13_3  9202-309_3  9204-33_3  9207-60_3  9211-19_3  9212-22_3  \
#  SampleId
#  TAC1145_BL     2950.0      1894.1      636.1     3068.7    63197.8     2521.2
#  TAC1000_BL     7869.2      7685.5      489.2     1507.6    57489.0     2201.4
#  TAC1058_BL     2828.3      2822.8      645.4     2429.1    53653.8     1937.3
#  TAC1150_BL     3559.3     13755.8      987.8     5549.8    53542.5     2049.0
#  TAC1174_BL     3676.7      1498.4      779.9     2497.6    55372.4     2975.7
#  ...               ...         ...        ...        ...        ...        ...
#  TAC1042_BL     5209.1      7615.7      762.6     2473.0    55404.6     1635.9
#  TAC1232_BL     3878.0     19389.6      390.1      877.2    44690.6     4918.2
#  TAC1082_BL     3845.6      5016.3      708.1     2262.1    63573.6     2091.9
#  TAC1179_BL     3357.0      1106.0      660.3     2140.2    49439.2     1602.6
#  VAC2038_BL     3644.0      2620.5      663.9     3996.3    57319.5     3054.9
#
#  SeqId       9213-24_3  9215-117_3  9216-100_3
#  SampleId
#  TAC1145_BL     7522.2      1114.9      4627.6
#  TAC1000_BL     6938.8       804.8      4887.5
#  TAC1058_BL    14913.5      1242.0      4860.3
#  TAC1150_BL    24307.1       683.9      4903.5
#  TAC1174_BL    14636.7       925.1      7282.2
#  ...               ...         ...         ...
#  TAC1042_BL    27503.5       853.7      4388.6
#  TAC1232_BL    14205.2       996.6      6644.6
#  TAC1082_BL    25993.3      3415.6      4202.4
#  TAC1179_BL     2045.2       944.8      4605.7
#  VAC2038_BL    15101.4       948.9      4504.2
#
#  [140 rows x 1311 columns],
#  SeqId       2597-8_3  2654-19_1  2788-55_1  2967-8_1  3046-31_1  4336-2_1  \
#  SampleId
#  TAC1145_BL   16301.7     1628.1      689.4   12386.8     1732.7    2461.5
#  TAC1000_BL   10421.1     1220.8      426.4   11669.8     1042.4    1676.3
#  TAC1058_BL    9352.7     1337.1      668.6   15387.8     2402.8    1377.1
#  TAC1150_BL   11279.3     1355.2      390.8   12320.6     1350.4     216.0
#  TAC1174_BL   10622.2     1062.2      671.9   16307.8     1323.5     418.5
#  ...              ...        ...        ...       ...        ...       ...
#  TAC1042_BL    9384.1      943.9      814.4   10377.0     2250.5    1604.1
#  TAC1232_BL   11154.9     1281.2     1889.8   17802.6     1633.2    2509.2
#  TAC1082_BL    6652.2     1636.0     1102.0   11790.8      979.0    8813.5
#  TAC1179_BL   16324.1     1614.3      601.3   15779.1     1683.5     872.9
#  VAC2038_BL    7696.6     1052.6      740.3   10938.4     1233.0    6032.5
#
#  SeqId       4337-49_2  4673-13_2  4867-15_2  4924-32_1  ...  9199-6_3  \
#  SampleId                                                ...
#  TAC1145_BL   146207.9      559.6     1556.6     3055.8  ...    7101.8
#  TAC1000_BL   157654.1      787.4      512.5      775.7  ...    5669.6
#  TAC1058_BL   142311.8      225.7      499.3     1082.9  ...    6163.6
#  TAC1150_BL    41350.3      266.6      541.4      639.9  ...    5003.9
#  TAC1174_BL    87174.8      232.8      429.1      790.0  ...    8339.7
#  ...               ...        ...        ...        ...  ...       ...
#  TAC1042_BL   168041.4      390.0      582.6      970.9  ...    6390.7
#  TAC1232_BL   106927.8      676.0      607.3     2804.5  ...    5062.3
#  TAC1082_BL    92119.4      195.4      980.7      898.7  ...    6730.9
#  TAC1179_BL   157544.8      490.7     1247.4     1286.8  ...   12071.1
#  VAC2038_BL    20577.7      239.6      435.0      518.9  ...    4858.7
#
#  SeqId       9201-13_3  9202-309_3  9204-33_3  9207-60_3  9211-19_3  9212-22_3  \
#  SampleId
#  TAC1145_BL     2950.0      1894.1      636.1     3068.7    63197.8     2521.2
#  TAC1000_BL     7869.2      7685.5      489.2     1507.6    57489.0     2201.4
#  TAC1058_BL     2828.3      2822.8      645.4     2429.1    53653.8     1937.3
#  TAC1150_BL     3559.3     13755.8      987.8     5549.8    53542.5     2049.0
#  TAC1174_BL     3676.7      1498.4      779.9     2497.6    55372.4     2975.7
#  ...               ...         ...        ...        ...        ...        ...
#  TAC1042_BL     5209.1      7615.7      762.6     2473.0    55404.6     1635.9
#  TAC1232_BL     3878.0     19389.6      390.1      877.2    44690.6     4918.2
#  TAC1082_BL     3845.6      5016.3      708.1     2262.1    63573.6     2091.9
#  TAC1179_BL     3357.0      1106.0      660.3     2140.2    49439.2     1602.6
#  VAC2038_BL     3644.0      2620.5      663.9     3996.3    57319.5     3054.9
#
#  SeqId       9213-24_3  9215-117_3  9216-100_3
#  SampleId
#  TAC1145_BL     7522.2      1114.9      4627.6
#  TAC1000_BL     6938.8       804.8      4887.5
#  TAC1058_BL    14913.5      1242.0      4860.3
#  TAC1150_BL    24307.1       683.9      4903.5
#  TAC1174_BL    14636.7       925.1      7282.2
#  ...               ...         ...         ...
#  TAC1042_BL    27503.5       853.7      4388.6
#  TAC1232_BL    14205.2       996.6      6644.6
#  TAC1082_BL    25993.3      3415.6      4202.4
#  TAC1179_BL     2045.2       944.8      4605.7
#  VAC2038_BL    15101.4       948.9      4504.2
#
#  [140 rows x 1310 columns],
#  SeqId      Patient_ID
#  SampleId
#  TAC1145_BL    TAC1145
#  TAC1000_BL    TAC1000
#  TAC1058_BL    TAC1058
#  TAC1150_BL    TAC1150
#  TAC1174_BL    TAC1174
#  ...               ...
#  TAC1042_BL    TAC1042
#  TAC1232_BL    TAC1232
#  TAC1082_BL    TAC1082
#  TAC1179_BL    TAC1179
#  VAC2038_BL    VAC2038
#
#  [140 rows x 1 columns],
#  Empty DataFrame
#  Columns: []
#  Index: [TAC1145_BL, TAC1000_BL, TAC1058_BL, TAC1150_BL, TAC1174_BL, TAC1242_BL, VAC2042_BL, TAC1139_BL, VAC2005_BL, TAC1016_BL, TAC1184_BL, TAC1250_BL, TAC1125_BL, TAC1031_BL, TAC1171_BL, TAC1095_BL, TAC1072_BL, TAC1049_BL, TAC1208_BL, VAC2015_BL, VAC2000_BL, TAC1127_BL, TAC1003_BL, TAC1209_BL, TAC1008_BL, TAC1272_BL, VAC2047_BL, TAC1201_BL, TAC1078_BL, TAC1147_BL, VAC2028_BL, TAC1073_BL, VAC2034_BL, VAC2039_BL, TAC1167_BL, TAC1075_BL, TAC1017_BL, TAC1225_BL, TAC1122_BL, TAC1089_BL, TAC1020_BL, TAC1110_BL, TAC1055_BL, TAC1218_BL, TAC1050_BL, TAC1269_BL, TAC1038_BL, TAC1148_BL, TAC1239_BL, TAC1212_BL, VAC2048_BL, TAC1140_BL, VAC2017_BL, VAC2011_BL, VAC2010_BL, TAC1227_BL, TAC1044_BL, VAC2046_BL, VAC2026_BL, VAC2024_BL, VAC2002_BL, TAC1247_BL, VAC2021_BL, TAC1205_BL, TAC1273_BL, TAC1012_BL, TAC1202_BL, TAC1085_BL, VAC2003_BL, TAC1283_BL, TAC1194_BL, TAC1221_BL, VAC2025_BL, TAC1021_BL, VAC2033_BL, TAC1204_BL, VAC2029_BL, VAC2027_BL, TAC1105_BL, VAC2018_BL, TAC1098_BL, TAC1196_BL, VAC2032_BL, VAC2007_BL, VAC2023_BL, TAC1146_BL, TAC1119_BL, TAC1230_BL, TAC1004_BL, VAC2006_BL, TAC1215_BL, VAC2009_BL, VAC2008_BL, TAC1190_BL, TAC1200_BL, TAC1043_BL, TAC1106_BL, TAC1206_BL, TAC1199_BL, TAC1080_BL, ...]
#
#  [140 rows x 0 columns])

# %%
#show_sheet_overview(df_exp_bl)
#show_dataset_structure(df_exp_bl)
inspect_omics_dataset(df_exp_bl)
# Out:
# ===== OMICS DATASET =====
#
# SAMPLE:
# SeqId      Patient_ID  2597-8_3  2654-19_1  2788-55_1  2967-8_1  3046-31_1  \
# SampleId
# TAC1062_BL    TAC1062    6591.6     1289.8      684.6    9150.9     1690.3
# TAC1232_BL    TAC1232   11154.9     1281.2     1889.8   17802.6     1633.2
# TAC1089_BL    TAC1089   10259.9     1377.0      628.0   13080.5     1771.6
# VAC2005_BL    VAC2005   10385.8     1332.2      452.9   18318.0     1776.6
# VAC2034_BL    VAC2034    9304.8     1024.8      592.9    9729.1     1218.0
#
# SeqId       4336-2_1  4337-49_2  4673-13_2  4867-15_2  ...  9199-6_3  \
# SampleId                                               ...
# TAC1062_BL    4513.9   172215.3      332.3      438.7  ...    6008.1
# TAC1232_BL    2509.2   106927.8      676.0      607.3  ...    5062.3
# TAC1089_BL     312.0   114379.8      300.6      501.4  ...    7344.7
# VAC2005_BL     541.7    22917.5      229.6      452.2  ...    4855.8
# VAC2034_BL     512.6    82933.7      237.6      364.4  ...    5105.0
#
# SeqId       9201-13_3  9202-309_3  9204-33_3  9207-60_3  9211-19_3  9212-22_3  \
# SampleId
# TAC1062_BL     3127.0      2032.1      523.3     2619.5    41594.7     1940.5
# TAC1232_BL     3878.0     19389.6      390.1      877.2    44690.6     4918.2
# TAC1089_BL     4320.1      2838.6      595.2     3228.9    66065.0     2899.5
# VAC2005_BL     2662.9      1337.8      999.5     1093.0    62845.6     1646.3
# VAC2034_BL     3364.9      2709.6      414.3     2736.4    52861.7     2299.6
#
# SeqId       9213-24_3  9215-117_3  9216-100_3
# SampleId
# TAC1062_BL     9773.7      1277.3      5855.4
# TAC1232_BL    14205.2       996.6      6644.6
# TAC1089_BL    49343.3      1297.0      5230.6
# VAC2005_BL    29015.5      1390.3      4900.9
# VAC2034_BL     9652.8       851.3      5849.9
#
# [5 rows x 1311 columns]
# SHAPE:
# (140, 1311)
#
# DTYPES:
# SeqId
# Patient_ID        str
# 2597-8_3      float64
# 2654-19_1     float64
# 2788-55_1     float64
# 2967-8_1      float64
#                ...
# 9211-19_3     float64
# 9212-22_3     float64
# 9213-24_3     float64
# 9215-117_3    float64
# 9216-100_3    float64
# Length: 1311, dtype: object
#
# MISSING VALUES (Top 10):
# SeqId
# Patient_ID    0
# 2597-8_3      0
# 2654-19_1     0
# 2788-55_1     0
# 2967-8_1      0
# 3046-31_1     0
# 4336-2_1      0
# 4337-49_2     0
# 4673-13_2     0
# 4867-15_2     0
# dtype: int64
#
# DTYPES (10 random samples):
# SeqId
# 5122-92_2    float64
# 3635-76_4    float64
# 3082-9_2     float64
# 2668-70_2    float64
# 2988-57_2    float64
# 5346-24_3    float64
# 2991-9_2     float64
# 5183-53_3    float64
# 2623-54_4    float64
# 5062-60_3    float64
# dtype: object
#
# SHORT NUMERIC SUMMARY (random 10 samples):
#            count          mean           std      min        25%       50%  \
# SeqId
# 2870-29_2  140.0  16580.497143  11649.362170   3983.4   9481.775  13312.95
# 3538-26_1  140.0    222.613571    241.288805    127.7    166.725    185.75
# 4450-26_2  140.0   1549.768571    541.950564    889.9   1236.400   1411.75
# 5008-51_1  140.0  48427.017857  12798.499083  23160.1  39105.475  46290.70
# 9182-3_3   140.0   1811.705000   1760.684472    603.5   1075.075   1470.75
# 4132-27_2  140.0    706.182143   1616.234816    338.6    444.600    503.80
# 5355-69_3  140.0    497.468571    234.629288    312.3    378.900    427.55
# 5246-64_3  140.0   6032.987143    948.772889   4256.2   5331.300   5898.60
# 3046-31_1  140.0   1556.068571    515.048531    726.7   1226.800   1486.45
# 4278-14_3  140.0    149.432143    150.853422     68.8    103.775    127.35
#
#                  75%      max
# SeqId
# 2870-29_2  20137.450  80689.3
# 3538-26_1    212.575   2849.1
# 4450-26_2   1663.525   4362.6
# 5008-51_1  55395.375  89334.8
# 9182-3_3    1878.175  16764.8
# 4132-27_2    610.925  19402.4
# 5355-69_3    527.575   2306.2
# 5246-64_3   6432.600   9031.9
# 3046-31_1   1758.625   5411.4
# 4278-14_3    149.800   1815.3

# %%
gene_lookup = pd.read_parquet('../mid_processing_datasets/gene_lookup.parquet')
gene_lookup.loc['5202-4_3']
# Out:
# EntrezGeneSymbol                                     PPID
# EntrezGeneID                                         5481
# Target                                               PPID
# TargetFullName      Peptidyl-prolyl cis-trans isomerase D
# UniProt                                            Q08752
# Name: 5202-4_3, dtype: str

# %%
normalize_num_dtype(df_exp_bl)
# Out:
# SeqId      Patient_ID      2597-8_3    2654-19_1    2788-55_1      2967-8_1  \
# SampleId
# TAC1145_BL    TAC1145  16301.700195  1628.099976   689.400024  12386.799805
# TAC1000_BL    TAC1000  10421.099609  1220.800049   426.399994  11669.799805
# TAC1058_BL    TAC1058   9352.700195  1337.099976   668.599976  15387.799805
# TAC1150_BL    TAC1150  11279.299805  1355.199951   390.799988  12320.599609
# TAC1174_BL    TAC1174  10622.200195  1062.199951   671.900024  16307.799805
# ...               ...           ...          ...          ...           ...
# TAC1042_BL    TAC1042   9384.099609   943.900024   814.400024       10377.0
# TAC1232_BL    TAC1232  11154.900391  1281.199951  1889.800049  17802.599609
# TAC1082_BL    TAC1082   6652.200195       1636.0       1102.0  11790.799805
# TAC1179_BL    TAC1179  16324.099609  1614.300049   601.299988  15779.099609

# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 2
#       1 from src.visualize import visualize_timepoints
# ----> 2 visualize_timepoints()
#
# File ~\Personal\HCW\Sommersemester\26\Biomedizinische Analytik mit KI 1\proj\src\visualize.py:19, in visualize_timepoints()
#      11 """PCA visualization of TAC patients at Baseline vs 6 months.
#      12
#      13 Creates three plots:
#    (...)     16 3. Trajectory plot showing patient movement from BL to 6M
#      17 """
#      18 # 1. Beide Zeitpunkte laden
# ---> 19 df_bl = pd.read_parquet('../mid_processing_datasets/expression_matrix_bl.parquet')
#      20 df_6m = pd.read_parquet('../mid_processing_datasets/expression_matrix_6m.parquet')
#      22 # 2. Nur TAC-Patienten (VAC ausfiltern)
#
# File c:\Users\chowe\Personal\HCW\Sommersemester\26\Biomedizinische Analytik mit KI 1\proj\venv\Lib\site-packages\pandas\io\parquet.py:671, in read_parquet(path, engine, columns, storage_options, dtype_backend, filesystem, filters, to_pandas_kwargs, **kwargs)
#     668 impl = get_engine(engine)
#     669 check_dtype_backend(dtype_backend)
# --> 671 return impl.read(
#     672     path,
#     673     columns=columns,
#     674     filters=filters,
#     675     storage_options=storage_options,
#     676     dtype_backend=dtype_backend,
#     677     filesystem=filesystem,
#     678     to_pandas_kwargs=to_pandas_kwargs,
#     679     **kwargs,
#     680 )
#
# File c:\Users\chowe\Personal\HCW\Sommersemester\26\Biomedizinische Analytik mit KI 1\proj\venv\Lib\site-packages\pandas\io\parquet.py:253, in PyArrowImpl.read(self, path, columns, filters, dtype_backend, storage_options, filesystem, to_pandas_kwargs, **kwargs)
#     240 def read(
#     241     self,
#     242     path,
#    (...)    249     **kwargs,
#     250 ) -> DataFrame:
#     251     kwargs["use_pandas_metadata"] = True
# --> 253     path_or_handle, handles, filesystem = _get_path_or_handle(
#     254         path,
#     255         filesystem,
#     256         storage_options=storage_options,
#     257         mode="rb",
#     258     )
#     259     try:
#     260         pa_table = self.api.parquet.read_table(
#     261             path_or_handle,
#     262             columns=columns,
#    (...)    265             **kwargs,
#     266         )
#
# File c:\Users\chowe\Personal\HCW\Sommersemester\26\Biomedizinische Analytik mit KI 1\proj\venv\Lib\site-packages\pandas\io\parquet.py:141, in _get_path_or_handle(path, fs, storage_options, mode, is_dir)
#     131 handles = None
#     132 if (
#     133     not fs
#     134     and not is_dir
#    (...)    139     # fsspec resources can also point to directories
#     140     # this branch is used for example when reading from non-fsspec URLs
# --> 141     handles = get_handle(
#     142         path_or_handle, mode, is_text=False, storage_options=storage_options
#     143     )
#     144     fs = None
#     145     path_or_handle = handles.handle
#
# File c:\Users\chowe\Personal\HCW\Sommersemester\26\Biomedizinische Analytik mit KI 1\proj\venv\Lib\site-packages\pandas\io\common.py:935, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     926         handle = open(
#     927             handle,
#     928             ioargs.mode,
#    (...)    931             newline="",
#     932         )
#     933     else:
#     934         # Binary mode
# --> 935         handle = open(handle, ioargs.mode)
#     936     handles.append(handle)
#     938 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: '../mid_processing_datasets/expression_matrix_bl.parquet'
