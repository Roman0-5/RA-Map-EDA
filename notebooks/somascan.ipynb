# %% [markdown]
# # Somascan EDA
# not done yet

# %% [markdown]
# # Setup & Imports

# %%
print("Loading Libraries")
# Core Libraries
import pandas as pd # excel tools
import openpyxl as opx #more excel tools
import numpy as np # math
print("Done loading")

# %% [markdown]
# # Load Data from Excel Sheet
# Loading from the Sheet and organising it through their sheets

# %%
#reading from excel file
all_sheets = pd.read_excel('../RA/13322471/SOMASCAN_RA-Map_figshare_17_11_20.xlsx', sheet_name=None)
#extracting sheet names
print(all_sheets.keys())
df_expMatrix = all_sheets['expression matrix']
df_sampMatrix = all_sheets['sample matrix']
#columns and rows per sheet
for name, sheet in all_sheets.items():
    print(f'{name}: {sheet.shape[0]} rows x {sheet.shape[1]} columns')

# %% [markdown]
# ---
# ## First look at Data
# Here we take a look at the structure of the Data (cell/column names)

# %%
df_sampMatrix.info()

# %%
# whole Glossary to get familiar with terms
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)
df_sampMatrix.head()

# %%
# first and last five of regular clinical metadata 
display(df_expMatrix.head())
display(df_expMatrix.tail())

# %%
# first and last five of steroids used
display(df_sampMatrix.head())
display(df_sampMatrix.tail())
df_expMatrix

# %%
df_expMatrix[df_expMatrix['Organism'] != 'Human']

# %%
df_expMatrix[df_expMatrix['Type']]
