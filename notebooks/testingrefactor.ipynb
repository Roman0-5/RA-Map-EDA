# %% [markdown]
# # Testing File
# Testing out method calls, exemplary walk through of code

# %%
# import * only used for testing purposes
from src.cleaning import *
from src.check_data import *
from src.load_data import *

# %%
ra_data = load_all_sheets()
df_clinical = ra_data['df_clinical']
# Out:
# Loading clinical...
# Loading protogen...
# Loading somascan...
# Done loading

# %%
ra_data['df_clinical'].shape
# Out:
# (327, 67)

# %%
df_clinical.shape
# Out:
# (327, 67)
