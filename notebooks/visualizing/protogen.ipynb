# %% [markdown]
# # Plots
# Delivers raw and log2 plots of
# - Histogram Distribution Plot
# - PCA Plot
# - Sree Plot
# - Box Plot

# %%
from src.common_imports import *
from src.visualizing_pipeline import visualize_raw
from src.log2_visualizing_pipeline import visualize_log
# Out:
# Loading Libraries
# Done loading

# %%
df_prot = pd.read_parquet('../../mid_processing_datasets/protogen_features_bl.parquet')

# %%
visualize_raw(df_prot, 'protogen dataset')
# Out:
# ...
# RAW EDA: PROTOGEN DATASET
# ...
# Shape: (265, 163)
# Value range: [9.0, 287408.0]
# Saved: ../../reports/raw/protogen dataset_distribution.svg
# Saved: ../../reports/raw/protogen dataset_pca_scatter.svg
# Saved: ../../reports/raw/protogen dataset_scree.svg
# Saved: ../../reports/raw/protogen dataset_boxplot_top20.svg
#
# Done with protogen dataset

# %%
visualize_log(df_prot, 'log2 protogen dataset')
# Out:
# ...
# LOG2 EDA: LOG2 PROTOGEN DATASET
# ...
# Shape: (265, 163)
# Log2 value range: [3.32, 18.13]
# Saved: ../../reports/log2/log2 protogen dataset_log2_distribution.svg
# Saved: ../../reports/log2/log2 protogen dataset_log2_pca_scatter.svg
# Saved: ../../reports/log2/log2 protogen dataset_log2_scree.svg
# Saved: ../../reports/log2/log2 protogen dataset_log2_boxplot_top20.svg
#
# Done with log2 protogen dataset
