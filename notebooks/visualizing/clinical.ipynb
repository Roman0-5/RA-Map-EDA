# %% [markdown]
# # Plots
# Delivers raw and log2 plots of
# - Histogram Distribution Plot
# - PCA Plot
# - Sree Plot
# - Box Plot

# %%
from src.common_imports import *
from src.visualizing_pipeline import visualize_raw
from src.log2_visualizing_pipeline import visualize_log
# Out:
# Loading Libraries
# Done loading

# %%
df_clinical = pd.read_parquet('../../mid_processing_datasets/clinical_merged.parquet')

# %%
visualize_raw(df_clinical, name='clinical')
# Out:
# ======================================================================
# RAW EDA: CLINICAL
# ======================================================================
# Shape: (275, 60)
# Value range: [0.0, 9220.0]
# Saved: ../../reports/raw/clinical_distribution.svg
# Saved: ../../reports/raw/clinical_pca_scatter.svg
# Saved: ../../reports/raw/clinical_scree.svg
# Saved: ../../reports/raw/clinical_boxplot_top20.svg
#
# Done with clinical

# %%
visualize_log(df_clinical, name='clinical')
# Out:
# ======================================================================
# LOG2 EDA: CLINICAL
# ======================================================================
# Shape: (275, 60)
# Log2 value range: [0.00, 13.17]
# Saved: ../../reports/log2/clinical_log2_distribution.svg
# Saved: ../../reports/log2/clinical_log2_pca_scatter.svg
# Saved: ../../reports/log2/clinical_log2_scree.svg
# Saved: ../../reports/log2/clinical_log2_boxplot_top20.svg
#
# Done with clinical
