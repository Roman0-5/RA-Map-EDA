# %%
from src.common_imports import *
from src.visualizing_pipeline import visualize_raw
from src.log2_visualizing_pipeline import visualize_log

# %%
df_clinical = pd.read_parquet('../../mid_processing_datasets/clinical_merged.parquet')

# %%
visualize_raw(df_clinical, name='clinical')
# Out:
# ======================================================================
# RAW EDA: CLINICAL
# ======================================================================
# Shape: (275, 60)
# Value range: [0.0, 9220.0]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 visualize_raw(df_clinical, name='clinical')
#
# File ~\Personal\HCW\Sommersemester\26\Biomedizinische Analytik mit KI 1\proj\src\visualizing_pipeline.py:54, in visualize_raw(df, name, output_dir, top_n_boxplot, n_show_scree)
#      51 print(f"Value range: [{X.min().min():.1f}, {X.max().max():.1f}]")
#      53 # 1. Verteilung
# ---> 54 plot_distribution(X, name, output_dir, xlabel='Raw value')
#      56 # 2. PCA + Scree (gemeinsame Vorbereitung)
#      57 X_scaled, pca = prepare_pca(X)
#
# File ~\Personal\HCW\Sommersemester\26\Biomedizinische Analytik mit KI 1\proj\src\visualizing_helper.py:27, in plot_distribution(X, name, output_dir, xlabel)
#      18 """Histogram of all numeric values in the dataset.
#      19
#      20 Args:
#    (...)     24     xlabel: Label for x-axis (e.g. 'RFU' or 'log2(RFU + 1)').
#      25 """
#      26 all_values = X.values.flatten()
# ---> 27 all_values = all_values[~np.isnan(all_values)]
#      29 fig, ax = plt.subplots(figsize=(10, 5))
#      30 ax.hist(all_values, bins=100, color='steelblue', alpha=0.7)
#
# NameError: name 'np' is not defined

# %%
visualize_log(df_clinical, name='clinical')
