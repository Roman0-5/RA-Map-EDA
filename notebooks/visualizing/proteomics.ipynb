# %%
from src.visualize import visualize_timepoints
from src.visualize_plots import *
from src.common_imports import *
# Out:
# Loading Libraries
# Done loading

# %%
df_bl = pd.read_parquet('../../mid_processing_datasets/expression_matrix_baseline.parquet')
df_m6 = pd.read_parquet('../../mid_processing_datasets/expression_matrix_6month.parquet')

# %%
plot_value_distribution(df_bl, 'baseline proteomics', '../../reports')
plot_value_distribution(df_m6, '6month proteomics', '../../reports')
# Out:
# Saved: ../../reports/baseline proteomics_value_distribution.svg
# Saved: ../../reports/6month proteomics_value_distribution.svg

# %%
plot_outlier_boxplot(df_bl, 'baseline proteomics', '../../reports')
plot_outlier_boxplot(df_m6, '6month proteomics', '../../reports')
# Out:
# Saved: ../../reports/baseline proteomics_boxplot_top20.svg
# Saved: ../../reports/6month proteomics_boxplot_top20.svg

# %%
plot_missing_heatmap(df_bl, 'baseline proteomics', '../../reports')
plot_missing_heatmap(df_m6, '6month proteomics', '../../reports')
# Out:
# Saved: ../../reports/baseline proteomics_missing_heatmap.svg
# Saved: ../../reports/6month proteomics_missing_heatmap.svg

# %%
plot_variance_distribution(df_bl, 'baseline proteomics', '../../reports')
plot_variance_distribution(df_m6, '6month proteomics', '../../reports')
# Out:
# Saved: ../../reports/baseline proteomics_variance.svg
# Saved: ../../reports/6month proteomics_variance.svg
