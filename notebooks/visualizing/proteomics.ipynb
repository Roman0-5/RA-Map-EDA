# %%
from src.common_imports import *
from src.visualizing_pipeline import visualize_raw
from src.log2_visualizing_pipeline import visualize_log
# Out:
# Loading Libraries
# Done loading

# %%
df_exp = pd.read_parquet('../../mid_processing_datasets/expression_matrix_baseline.parquet')

# %%
visualize_raw(df_exp, 'baseline proteomics')
# Out:
# ...
# RAW EDA: BASELINE PROTEOMICS
# ...
# Shape: (140, 1310)
# Value range: [26.3, 399890.2]
# Saved: ../reports/raw/baseline proteomics_distribution.svg
# Saved: ../reports/raw/baseline proteomics_pca_scatter.svg
# Saved: ../reports/raw/baseline proteomics_scree.svg
# Saved: ../reports/raw/baseline proteomics_boxplot_top20.svg
#
# Done with baseline proteomics

# %%
visualize_log(df_exp,'log2 baseline proteomics')
# Out:
# ...
# LOG2 EDA: LOG 2BASELINE PROTEOMICS
# ...
# Shape: (140, 1310)
# Log2 value range: [4.77, 18.61]
# Saved: ../reports/log2/log 2baseline proteomics_log2_distribution.svg
# Saved: ../reports/log2/log 2baseline proteomics_log2_pca_scatter.svg
# Saved: ../reports/log2/log 2baseline proteomics_log2_scree.svg
# Saved: ../reports/log2/log 2baseline proteomics_log2_boxplot_top20.svg
#
# Done with log 2baseline proteomics
