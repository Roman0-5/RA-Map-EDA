# %% [markdown]
# # Plots
# Delivers raw and log2 plots of
# - Histogram Distribution Plot
# - PCA Plot
# - Sree Plot
# - Box Plot

# %%
import pandas as pd

from src.visualizing_pipeline import visualize_raw
from src.log2_visualizing_pipeline import visualize_log
from src.featsel import run_correlation_selection
# Out:
# Loading Libraries
# Done loading

# %%
expr_bl = pd.read_parquet('../../mid_processing_datasets/expression_matrix_baseline.parquet')
clinical = pd.read_parquet('../../mid_processing_datasets/clinical_merged.parquet')

# %%
visualize_raw(
    df = expr_bl, name='expression_bl',
    output_dir = "../../reports/raw",
    clinical_df = clinical,
    label_type = 'eular' 
)
visualize_raw(
    df = expr_bl, name='expression_bl',
    output_dir = "../../reports/raw",
    clinical_df = clinical,
    label_type = 'remission' 
)
# Out:
# ======================================================================
# RAW EDA: BASELINE PROTEOMICS
# ======================================================================
# Shape: (140, 1310)
# Value range: [26.3, 399890.2]
# Saved: ../../reports/raw/baseline proteomics_distribution.svg
# Saved: ../../reports/raw/baseline proteomics_pca_scatter.svg
# Saved: ../../reports/raw/baseline proteomics_scree.svg
# Saved: ../../reports/raw/baseline proteomics_boxplot_top20.svg
#
# Done with baseline proteomics

# %%
visualize_log(
    df         = expr_bl,
    name       = "expression_bl",
    output_dir = "../../reports/log2",
    clinical_df= clinical,
    label_type = "eular",
)
visualize_log(
    df         = expr_bl,
    name       = "expression_bl",
    output_dir = "../../reports/log2",
    clinical_df= clinical,
    label_type = "remission",
)
# Out:
# ======================================================================
# LOG2 EDA: LOG2 BASELINE PROTEOMICS
# ======================================================================
# Shape: (140, 1310)
# Log2 value range: [4.77, 18.61]
# Saved: ../../reports/log2/log2 baseline proteomics_log2_distribution.svg
# Saved: ../../reports/log2/log2 baseline proteomics_log2_pca_scatter.svg
# Saved: ../../reports/log2/log2 baseline proteomics_log2_scree.svg
# Saved: ../../reports/log2/log2 baseline proteomics_log2_boxplot_top20.svg
#
# Done with log2 baseline proteomics

# %%
df_reduced_expr, to_keep_expr, to_drop_expr = run_correlation_selection(
    df = expr_bl, name = 'expression_bl',
    threshold = 0.95, output_dir = '../../reports/feature_selection'
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 4
#       2 import matplotlib.pyplot as plt
#       3 df = pd.DataFrame(df_exp)
# ----> 4 correlation_matrix = df.corr()
#       5 plt.figure(figsize=(10,8))
#       6 sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0)
#
# File c:\Users\chowe\Personal\HCW\Sommersemester\26\Biomedizinische Analytik mit KI 1\proj\venv\Lib\site-packages\pandas\core\frame.py:13117, in DataFrame.corr(self, method, min_periods, numeric_only)
#   13115 cols = data.columns
#   13116 idx = cols.copy()
# > 13117 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   13119 if method == "pearson":
#   13120     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\chowe\Personal\HCW\Sommersemester\26\Biomedizinische Analytik mit KI 1\proj\venv\Lib\site-packages\pandas\core\frame.py:2081, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    2079 if dtype is not None:
#    2080     dtype = np.dtype(dtype)
# -> 2081 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    2082 if result.dtype is not dtype:
#    2083     result = np.asarray(result, dtype=dtype)
#
# File c:\Users\chowe\Personal\HCW\Sommersemester\26\Biomedizinische Analytik mit KI 1\proj\venv\Lib\site-packages\pandas\core\internals\managers.py:1864, in BlockManager.as_array(self, dtype, copy, na_value)
#    1862         arr.flags.writeable = False
#    1863 else:
# -> 1864     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1865     # The underlying data was copied within _interleave, so no need
#    1866     # to further copy if copy=True or setting na_value
#    1868 if na_value is lib.no_default:
#
# File c:\Users\chowe\Personal\HCW\Sommersemester\26\Biomedizinische Analytik mit KI 1\proj\venv\Lib\site-packages\pandas\core\internals\managers.py:1917, in BlockManager._interleave(self, dtype, na_value)
#    1911 rl = blk.mgr_locs
#    1912 if blk.is_extension:
#    1913     # Avoid implicit conversion of extension blocks to object
#    1914
#    1915     # error: Item "ndarray" of "Union[ndarray, ExtensionArray]" has no
#    1916     # attribute "to_numpy"
# -> 1917     arr = blk.values.to_numpy(  # type: ignore[union-attr]
#    1918         dtype=dtype,
#    1919         na_value=na_value,
#    1920     )
#    1921 else:
#    1922     arr = blk.get_values(dtype)
#
# File c:\Users\chowe\Personal\HCW\Sommersemester\26\Biomedizinische Analytik mit KI 1\proj\venv\Lib\site-packages\pandas\core\arrays\arrow\array.py:1717, in ArrowExtensionArray.to_numpy(self, dtype, copy, na_value)
#    1715 result = data._pa_array.to_numpy()
#    1716 if dtype is not None:
# -> 1717     result = result.astype(dtype, copy=False)
#    1718 if copy:
#    1719     result = result.copy()
#
# ValueError: could not convert string to float: 'TAC1145'
