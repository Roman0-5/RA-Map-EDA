# %%
from src.build_multiomics import build_multiomics

df = build_multiomics(
    clinical_path = "../../mid_processing_datasets/clinical_merged.parquet",
    expr_bl_path  = "../../mid_processing_datasets/expression_matrix_baseline.parquet",
    protogen_path = "../../mid_processing_datasets/protogen_merged_bl.parquet",
    output_path   = "../../mid_processing_datasets/multiomics_bl.parquet",
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from src.build_multiomics import build_multiomics
#       3 df = build_multiomics(
#       4     clinical_path = "../../mid_processing_datasets/clinical_merged.parquet",
#       5     expr_bl_path  = "../../mid_processing_datasets/expression_matrix_baseline.parquet",
#       6     protogen_path = "../../mid_processing_datasets/protogen_merged_bl.parquet",
#       7     output_path   = "../../mid_processing_datasets/multiomics_bl.parquet",
#       8 )
#
# ImportError: cannot import name 'build_multiomics' from 'src.build_multiomics' (C:\Users\chowe\Personal\HCW\Sommersemester\26\Biomedizinische Analytik mit KI 1\proj\src\build_multiomics.py)
