# %%
from src.build_multiomics import build_multiomics

df = build_multiomics(
    clinical_path = "../../mid_processing_datasets/clinical_merged.parquet",
    expr_bl_path  = "../../mid_processing_datasets/expression_matrix_baseline.parquet",
    protogen_path = "../../mid_processing_datasets/protogen_merged_bl.parquet",
    output_path   = "../../mid_processing_datasets/multiomics_bl.parquet",
)
# Out:
# ======================================================================
# BUILDING MULTI-OMICS DATASET
# ======================================================================
#
# Loading files …
#   clinical  : (275, 68)
#   expr_bl   : (140, 1311)
#   protogen  : (265, 168)
#
# Patient overlap:
#   clinical  : 275
#   expr_bl   : 140
#   protogen  : 265
#   inner join: 100
#
# Merging …
#
# Merged shape: (100, 1541)
#   Patient_ID + clinical features : 67
#   Expression features (expr_*)   : 1310
#   Protogen features   (pg_*)     : 163
#   Total columns                  : 1541
#
# Missing values: 440 / 154100 (0.29%)
# Columns with any NaN: 33
#
# Saved: ../../mid_processing_datasets/multiomics_bl.parquet
