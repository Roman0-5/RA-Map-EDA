# %%
from src.build_multiomics import build_multiomics

df = build_multiomics(
    clinical_path = "../../cleaned_datasets/clinical_merged.parquet",
    exp_bl_path   = "../../cleaned_datasets/exp_bl.parquet",
    exp_m6_path   = "../../cleaned_datasets/exp_m6.parquet",
    pg_feat_path  = "../../cleaned_datasets/protogen_features.parquet",
    pg_meta_path  = "../../cleaned_datasets/protogen_metadata.parquet",
    output_path   = "../../cleaned_datasets/multiomics.parquet",
)
