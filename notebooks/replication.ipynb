# %%
from src.autoantibody_eda import *

# %%
autoantibody()
# Out:
# Matrix:     (163, 481)  (Antigene x Samples)
# Klinik:     (481, 6)
# Timepoints: {'Baseline': 247, '6-month': 234}
# ALCOHOL dtype: str | Beispiele: <ArrowStringArray>
# ['Yes', 'No']
# Length: 2, dtype: str
#
# [1/5] Mean-Variance Plot ...
#    -> 01_mean_variance.png gespeichert
# [2/5] Density Plot ...
#    -> 02_density.png gespeichert
# [3/5] Subject Similarity Matrix ...
#    -> 03_similarity_matrix.png gespeichert
# [4/5] PCA ...
#    -> 04_pca.png gespeichert
# [5/5] Drivers Plot ...
#    Drivers-Subset nach na.omit: 472 Samples
#    -> 05_drivers.png gespeichert
#
# Alle Plots gespeichert in: ../reports/replicating/
